# %%
import pandas as pd

# %%
all_df = pd.read_csv("data/JC-20201-citibike-tripdata.csv")
for i in range(2, 13):
    df = pd.read_csv(f"data/JC-2020{i}-citibike-tripdata.csv")
    all_df = pd.concat([all_df, df], axis=0)

# %%
all_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
# Save to csv
all_df.to_csv('data/alldata_df.csv')

# %%
sum =pd.read_csv("data/summer/JC-20204-citibike-tripdata.csv")
for i in range(5,10):
    df = pd.read_csv(f"data/summer/JC-2020{i}-citibike-tripdata.csv")
    sum = pd.concat([sum, df], axis=0)
    
sum
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1437  2020-04-01 01:06:20.6300  2020-04-01 01:30:17.9680
# 1               264  2020-04-01 05:02:42.0570  2020-04-01 05:07:06.1260
# 2               254  2020-04-01 06:20:28.1190  2020-04-01 06:24:42.1380
# 3               429  2020-04-01 06:33:30.5170  2020-04-01 06:40:40.1990
# 4               805  2020-04-01 06:38:32.9220  2020-04-01 06:51:58.2050
# ...             ...                       ...                       ...
# 53828           270  2020-10-13 15:05:35.0860  2020-10-13 15:10:05.3430
# 53829           400  2020-10-13 15:09:03.4890  2020-10-13 15:15:43.9750
# 53830           206  2020-10-13 15:11:34.3500  2020-10-13 15:15:00.5030
# 53831           216  2020-10-13 15:11:49.1510  2020-10-13 15:15:25.6930
# 53832           418  2020-10-13 15:12:31.7920  2020-10-13 15:19:30.5280
#
#        start station id start station name  start station latitude  \
# ...

# %%
new =sum.loc[(sum.starttime.str.contains('2020-10-01'))]
new
# Out:
#        tripduration                 starttime                  stoptime  \
# 40382           156  2020-10-01 00:02:40.2600  2020-10-01 00:05:17.0140
# 40383           143  2020-10-01 00:02:53.5020  2020-10-01 00:05:16.9650
# 40384           305  2020-10-01 00:04:31.3160  2020-10-01 00:09:36.3840
# 40385          1097  2020-10-01 00:05:18.3680  2020-10-01 00:23:36.1240
# 40386           277  2020-10-01 00:09:17.5990  2020-10-01 00:13:55.5150
# ...             ...                       ...                       ...
# 41543           655  2020-10-01 23:43:14.0040  2020-10-01 23:54:09.3840
# 41544           319  2020-10-01 23:46:29.0930  2020-10-01 23:51:48.8780
# 41545           701  2020-10-01 23:58:53.0800  2020-10-02 00:10:34.5780
# 41546           169  2020-10-01 23:58:56.3690  2020-10-02 00:01:46.0790
# 41547           681  2020-10-01 23:59:03.4510  2020-10-02 00:10:25.0470
#
#        start station id  start station name  start station latitude  \
# ...

# %%
#This should be run only once otw it drops everytime it runs
# Number of rows to drop
n = 13451
 
# Dropping last n rows using drop
sum.drop(sum.tail(n).index,
        inplace = True)

sum
# Out:
#        tripduration                 starttime                  stoptime  \
# 0              1437  2020-04-01 01:06:20.6300  2020-04-01 01:30:17.9680
# 1               264  2020-04-01 05:02:42.0570  2020-04-01 05:07:06.1260
# 2               254  2020-04-01 06:20:28.1190  2020-04-01 06:24:42.1380
# 3               429  2020-04-01 06:33:30.5170  2020-04-01 06:40:40.1990
# 4               805  2020-04-01 06:38:32.9220  2020-04-01 06:51:58.2050
# ...             ...                       ...                       ...
# 40377           202  2020-09-30 23:19:24.4580  2020-09-30 23:22:47.3030
# 40378           783  2020-09-30 23:24:00.7520  2020-09-30 23:37:04.5550
# 40379           491  2020-09-30 23:30:56.4610  2020-09-30 23:39:07.8370
# 40380           412  2020-09-30 23:50:49.6570  2020-09-30 23:57:42.1270
# 40381           212  2020-09-30 23:56:23.5830  2020-09-30 23:59:55.7960
#
#        start station id          start station name  start station latitude  \
# ...

# %%
win1 =pd.read_csv("data/winter/JC-20201-citibike-tripdata.csv")
for i in range(2,4):
    df = pd.read_csv(f"data/winter/JC-2020{i}-citibike-tripdata.csv")
    win1 = pd.concat([win1, df], axis=0)

# %%
win1
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1               377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2               288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3               435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4               231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...             ...                       ...                       ...
# 17714           296  2020-03-31 22:50:39.0410  2020-03-31 22:55:35.5980
# 17715           147  2020-03-31 23:09:15.9690  2020-03-31 23:11:43.5310
# 17716           364  2020-03-31 23:17:02.0240  2020-03-31 23:23:06.8200
# 17717          1217  2020-03-31 23:36:10.6430  2020-03-31 23:56:27.8120
# 17718           846  2020-03-31 23:37:21.1840  2020-03-31 23:51:28.1220
#
#        start station id start station name  start station latitude  \
# ...

# %%
win2 =pd.read_csv("data/winter/JC-202010-citibike-tripdata.csv")
for i in range(11,13):
    df = pd.read_csv(f"data/winter/JC-2020{i}-citibike-tripdata.csv")
    win2 = pd.concat([win2, df], axis=0)

# %%
win2
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               156  2020-10-01 00:02:40.2600  2020-10-01 00:05:17.0140
# 1               143  2020-10-01 00:02:53.5020  2020-10-01 00:05:16.9650
# 2               305  2020-10-01 00:04:31.3160  2020-10-01 00:09:36.3840
# 3              1097  2020-10-01 00:05:18.3680  2020-10-01 00:23:36.1240
# 4               277  2020-10-01 00:09:17.5990  2020-10-01 00:13:55.5150
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
df_col_merged = pd.concat([win1, win2], axis=0)
df_col_merged
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1               377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2               288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3               435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4               231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
# ...             ...                       ...                       ...
# 11689          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 11690          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 11691          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 11692           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 11693          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#        start station id start station name  start station latitude  \
# ...

# %%
# Save to csv
sum.to_csv('data/summer_df.csv')

# %%
df_col_merged.to_csv('data/winter_df.csv')
